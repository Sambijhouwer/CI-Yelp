# %%
import pandas as pd
import json
import numpy as np
from math import sqrt
def load_jsons(data_path, file):
    """ helper function to load '.json' files (they're not proper jsons) """
    file_path = data_path + file
    with open(file_path) as jsons:
        lines = [json.loads(json_line) for json_line in jsons]
    return pd.DataFrame(lines)

# %% [markdown]
# ### Data inladen
#
#     Load data for town called Ambridge
#     data_path = './data/ambridge/'
#     review_file = 'review.json'
#     business_file = 'business.json'
#     user_file = 'user.json'
#     tip_file = 'tip.json'
#     checkin_file = 'checkin.json'
#
#     reviews = load_jsons(data_path, review_file)
#     businesses = load_jsons(data_path, business_file)
#     users = load_jsons(data_path, user_file)
#     tips = load_jsons(data_path, tip_file)
#     checkins = load_jsons(data_path, checkin_file)

# %%
data_path = './data/akron/'
review_file = 'review.json'
business_file = 'business.json'
user_file = 'user.json'
tip_file = 'tip.json'
checkin_file = 'checkin.json'

reviews = load_jsons(data_path, review_file)
businesses = load_jsons(data_path, business_file)
users = load_jsons(data_path, user_file)
tips = load_jsons(data_path, tip_file)
checkins = load_jsons(data_path, checkin_file)

# %% [markdown]
# ### Utility Matrix

# %%
def pivot_ratings(ratings):
    """ takes a rating table as input and computes the utility matrix """
    return ratings.pivot_table(index='business_id', columns='user_id', values='stars').fillna(np.nan)

# %%
utility_matrix = pivot_ratings(reviews)
display(utility_matrix)
# Out:
# user_id                 --9Et6koJ2Apqk4nxuv3TQ  --tuEsv6L10jqcwBANrSnw  \
# business_id
# -0LPtgJC31FWMrMv317p0Q                     NaN                     NaN
# -6Lc2gIhLkggEdCMpVidlQ                     NaN                     NaN
# -CBW4yvallpWtfWBbZCHqg                     NaN                     NaN
# -SNFOrPHya_I4m6vj491UQ                     NaN                     NaN
# -YnOFIP-xZeWEwbatrDO9g                     NaN                     NaN
# ...                                        ...                     ...
# zNN5HBJ8w_ahxu-UyXtVLg                     NaN                     NaN
# zOHQdGK6D3S0rvyNsrQi0Q                     NaN                     NaN
# zgGCFFW9fmMve9iyeCJc0g                     NaN                     NaN
# zxxwy18lW8uviih0xzeuig                     NaN                     NaN
# zy9lwMhCU6vwC8Uff60iZg                     NaN                     NaN
#
# user_id                 -01kVTKImAOZTyAGAn-YZg  -0x2ov-qcCopv32Imm-TYg  \
# business_id
# -0LPtgJC31FWMrMv317p0Q                     NaN                     NaN
# -6Lc2gIhLkggEdCMpVidlQ                     NaN                     NaN
# -CBW4yvallpWtfWBbZCHqg                     NaN                     NaN
# -SNFOrPHya_I4m6vj491UQ                     NaN                     NaN
# -YnOFIP-xZeWEwbatrDO9g                     NaN                     NaN
# ...                                        ...                     ...
# zNN5HBJ8w_ahxu-UyXtVLg                     NaN                     NaN
# zOHQdGK6D3S0rvyNsrQi0Q                     NaN                     NaN
# zgGCFFW9fmMve9iyeCJc0g                     NaN                     NaN
# zxxwy18lW8uviih0xzeuig                     NaN                     NaN
# zy9lwMhCU6vwC8Uff60iZg                     NaN                     NaN
#
# user_id                 -1eUcYsPzr0K_nw67oohdw  -1sHorO23302dx_aJxUb4g  \
# business_id
# -0LPtgJC31FWMrMv317p0Q                     NaN                     NaN
# -6Lc2gIhLkggEdCMpVidlQ                     NaN                     NaN
# ### Mean Center Columns

# %%
def mean_center_columns(matrix):
    # TODO
    means = matrix.mean()
    matrix2 = matrix.apply(lambda x: x - means[x.name])
    return matrix2

centered_utility_matrix = mean_center_columns(utility_matrix)

# %% [markdown]
# ### Cosine Similarity

# %%
def cosine_distance(matrix, id1, id2):
    features1 = matrix.loc[id1]
    features2 = matrix.loc[id2]
    if features1.equals(features2):
        return 1.0

    selected_features = features1.notna() & features2.notna()
    
    if not selected_features.any() or not (features1.any() and features2.any()):
        return np.nan
    
    features1 = matrix.loc[id1][selected_features]
    features2 = matrix.loc[id2][selected_features]
    deler = sum(features1 * features2)
    noemer = math.sqrt(sum([x**2 for x in features1])) * sqrt(sum([x**2 for x in features2]))
    try:
        return deler/noemer
    except:
        return np.nan

def create_similarity_matrix_cosine(matrix):
    cosine_matrix = pd.DataFrame(0, index=matrix.index, columns=matrix.index, dtype=float)
    for x in matrix.index:
        for y in matrix.index:
            cosine_matrix.at[x,y] = cosine_distance(matrix, x, y)
    return cosine_matrix

# %%
sim_matrix_cosine_centered = create_similarity_matrix_cosine(centered_utility_matrix)

# %% [markdown]
# ### Save matrix as pickle

# %%
sim_matrix_cosine.to_pickle('./similarity_matrix.pkl')

# %%
sim_matrix_cosine_centered.to_pickle('./similarity_matrix_centered.pkl')

# %%
display(sim_matrix_cosine_centered)
# Out:
# business_id             -0LPtgJC31FWMrMv317p0Q  -6Lc2gIhLkggEdCMpVidlQ  \
# business_id
# -0LPtgJC31FWMrMv317p0Q                     1.0                     NaN
# -6Lc2gIhLkggEdCMpVidlQ                     NaN                     1.0
# -CBW4yvallpWtfWBbZCHqg                     NaN                     NaN
# -SNFOrPHya_I4m6vj491UQ                     NaN                     NaN
# -YnOFIP-xZeWEwbatrDO9g                     NaN                     NaN
# ...                                        ...                     ...
# zNN5HBJ8w_ahxu-UyXtVLg                     NaN                     NaN
# zOHQdGK6D3S0rvyNsrQi0Q                     1.0                     NaN
# zgGCFFW9fmMve9iyeCJc0g                     NaN                     NaN
# zxxwy18lW8uviih0xzeuig                     1.0                     NaN
# zy9lwMhCU6vwC8Uff60iZg                     NaN                     NaN
#
# business_id             -CBW4yvallpWtfWBbZCHqg  -SNFOrPHya_I4m6vj491UQ  \
# business_id
# -0LPtgJC31FWMrMv317p0Q                     NaN                     NaN
# -6Lc2gIhLkggEdCMpVidlQ                     NaN                     NaN
# -CBW4yvallpWtfWBbZCHqg                1.000000               -0.723951
# -SNFOrPHya_I4m6vj491UQ               -0.723951                1.000000
# -YnOFIP-xZeWEwbatrDO9g                     NaN                     NaN
# ...                                        ...                     ...
# zNN5HBJ8w_ahxu-UyXtVLg                1.000000                     NaN
# zOHQdGK6D3S0rvyNsrQi0Q                     NaN                1.000000
# zgGCFFW9fmMve9iyeCJc0g                     NaN                     NaN
# zxxwy18lW8uviih0xzeuig                     NaN                     NaN
# zy9lwMhCU6vwC8Uff60iZg                     NaN                     NaN
#
# business_id             -YnOFIP-xZeWEwbatrDO9g  -bHpvkmiFzm_swHLYsGiqw  \
# business_id
# -0LPtgJC31FWMrMv317p0Q                     NaN                     NaN
# business_id
# -0LPtgJC31FWMrMv317p0Q                     NaN                     NaN
# -6Lc2gIhLkggEdCMpVidlQ                     NaN                     NaN
# -CBW4yvallpWtfWBbZCHqg                     NaN                     NaN
# -SNFOrPHya_I4m6vj491UQ                     NaN                     NaN
# -YnOFIP-xZeWEwbatrDO9g                     NaN                     NaN
# ...                                        ...                     ...
# zNN5HBJ8w_ahxu-UyXtVLg                     NaN                     NaN
# zOHQdGK6D3S0rvyNsrQi0Q                     NaN                     NaN
# zgGCFFW9fmMve9iyeCJc0g                     NaN                     NaN
# zxxwy18lW8uviih0xzeuig                     NaN                     NaN
# zy9lwMhCU6vwC8Uff60iZg                     NaN                     NaN
#
# business_id             z6kCzBQt5Vv1KFkQgrhVnA  zNN5HBJ8w_ahxu-UyXtVLg  \
# business_id
# -0LPtgJC31FWMrMv317p0Q                     NaN                     NaN
# -6Lc2gIhLkggEdCMpVidlQ                     NaN                     NaN
# -CBW4yvallpWtfWBbZCHqg               -0.433255                     1.0
# -SNFOrPHya_I4m6vj491UQ                1.000000                     NaN
# -YnOFIP-xZeWEwbatrDO9g                     NaN                     NaN
# ...                                        ...                     ...
# zNN5HBJ8w_ahxu-UyXtVLg                     NaN                     1.0
# zOHQdGK6D3S0rvyNsrQi0Q                     NaN                     NaN
# zgGCFFW9fmMve9iyeCJc0g                     NaN                     NaN
# zxxwy18lW8uviih0xzeuig                     NaN                     NaN
# zy9lwMhCU6vwC8Uff60iZg                     NaN                     NaN
#
# business_id             zOHQdGK6D3S0rvyNsrQi0Q  zgGCFFW9fmMve9iyeCJc0g  \
# business_id
# -0LPtgJC31FWMrMv317p0Q                     1.0                     NaN
# -6Lc2gIhLkggEdCMpVidlQ                     NaN                     NaN
# -CBW4yvallpWtfWBbZCHqg                     NaN                     NaN
# -SNFOrPHya_I4m6vj491UQ                     1.0                     NaN
# -YnOFIP-xZeWEwbatrDO9g                     NaN                     NaN
# ...                                        ...                     ...
# zNN5HBJ8w_ahxu-UyXtVLg                     NaN                     NaN
# zOHQdGK6D3S0rvyNsrQi0Q                     1.0                     NaN
# zgGCFFW9fmMve9iyeCJc0g                     NaN                     1.0
# zxxwy18lW8uviih0xzeuig                     NaN                     NaN
# zy9lwMhCU6vwC8Uff60iZg                     NaN                     NaN
#
# business_id             zxxwy18lW8uviih0xzeuig  zy9lwMhCU6vwC8Uff60iZg
# business_id
# -0LPtgJC31FWMrMv317p0Q                     1.0                     NaN
# -6Lc2gIhLkggEdCMpVidlQ                     NaN                     NaN
# -CBW4yvallpWtfWBbZCHqg                     NaN                     NaN
# -SNFOrPHya_I4m6vj491UQ                     NaN                     NaN
# -YnOFIP-xZeWEwbatrDO9g                     NaN                     NaN
# ...                                        ...                     ...
# zNN5HBJ8w_ahxu-UyXtVLg                     NaN                     NaN
# zOHQdGK6D3S0rvyNsrQi0Q                     NaN                     NaN
# zgGCFFW9fmMve9iyeCJc0g                     NaN                     NaN
# zxxwy18lW8uviih0xzeuig                     1.0                     NaN
# zy9lwMhCU6vwC8Uff60iZg                     NaN                     1.0
#
# [465 rows x 465 columns]
